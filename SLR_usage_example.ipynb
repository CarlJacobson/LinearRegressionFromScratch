# %%
import cjlearn as cj
import numpy as np

# %%
from sklearn import linear_model

# %%
line = cj.random_line_maker(slope = 300, intercept = 0, variance = 100, points = 100)

# %%
model = linear_model.LinearRegression()
X=line.x.reshape(1, -1)
y=line.y.reshape(1, -1)
model.fit(X,y)
# Out:
# LinearRegression()

# %%
line.plot()

# %%
model = cj.models.slr()

# %%
model.fit(line)

# %%
model.plot()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Carld\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
model.predict(np.array([1,2,3,4,5]))
# Out:
# array([ 299.32835492,  598.90500238,  898.48164984, 1198.0582973 ,
#        1497.63494476])

# %%
model.beta0_hat
# Out:
# 0.005363722030843121
