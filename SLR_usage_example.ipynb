# %%
#importing package
import cjlearn as cj

# %%
# Creating a line object to generate data with given slope intercept and variance
line = cj.random_line_maker(slope = 5, intercept = 0, variance = 10, points = 200)

# %%
#Calling the built in plot function to display generated line data
line.plot()

# %%
# Initializing simple linear regression model object
model = cj.models.slr()

# %%
# Fitting data to model using OLS. 
# Function prints out formula of data when fit
model.fit(line)
# Out:
# Y = -29.5996 + 5.2439 * x

# %%
#Calling the built in plot function to display generated line data with calculated regression line
model.plot()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Carl\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#Calling built in predict function to calculate out of sample predictions
# Can take in ints, floats, or any iterable
model.predict([500,202,203,204,205])
# Out:
# array([2592.32562982, 1029.65821965, 1034.90207002, 1040.14592039,
#        1045.38977076])

# %%
model.predict(5)
# Out:
# -3.3803031826173857

# %%
model.beta0_hat
# Out:
# -29.59955503110075

# %%
model.beta1_hat
# Out:
# 5.2438503696966725

# %%
model.formula()
# Out:
# 'Y = -29.6 + 5.244 * x'
